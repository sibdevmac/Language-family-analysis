# %% [markdown]
# https://www.kaggle.com/datasets/waqi786/world-languages-dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('languages_dataset.csv')

# %%
df.head()
# Out:
#           Language         Family     Region  Speakers Writing System ISO Code
# 0           Yoruba  Indo-European      India  76000000          Latin       om
# 1     Southern Min  Indo-European      India  47000000          Latin       ru
# 2  Yue (Cantonese)      Dravidian      India  75000000     Devanagari       my
# 3          Spanish   Austronesian     Poland  76900000     Devanagari       it
# 4           Arabic  Indo-European  Worldwide  76000000         Hangul       ur

# %%
df.tail()
# Out:
#              Language         Family            Region   Speakers  \
# 495           Punjabi   Indo-Iranian             India   23000000
# 496           Spanish      Dravidian         Worldwide   76900000
# 497           English  Indo-European  Germany, Austria   28000000
# 498  Xiang (Hunanese)  Indo-European         Worldwide  460000000
# 499           Punjabi  Indo-European         Indonesia   83000000
#
#     Writing System ISO Code
# 495          Latin       ha
# 496          Tamil       bn
# 497          Latin      hak
# 498        Kannada       pa
# 499   Perso-Arabic       de

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Language        500 non-null    object
#  1   Family          500 non-null    object
#  2   Region          500 non-null    object
#  3   Speakers        500 non-null    int64
#  4   Writing System  500 non-null    object
#  5   ISO Code        489 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 23.6+ KB

# %%
df.columns
# Out:
# Index(['Language', 'Family', 'Region', 'Speakers', 'Writing System',
#        'ISO Code'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Speakers
# count  5.000000e+02
# mean   9.840200e+07
# std    1.414893e+08
# min    2.000000e+07
# 25%    2.800000e+07
# 50%    5.350000e+07
# 75%    7.690000e+07
# max    9.180000e+08

# %%
family_power = (
    df.groupby("Family")["Speakers"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

family_power
# Out:
#            Family     Speakers
# 0   Indo-European  20953500000
# 1    Sino-Tibetan   9129900000
# 2          Turkic   3376000000
# 3    Afro-Asiatic   2718000000
# 4       Dravidian   2629900000
# 5     Niger-Congo   2413000000
# 6   Austroasiatic   2065000000
# 7    Indo-Iranian   1995900000
# 8    Austronesian   1628800000
# 9         Japonic    860000000
# 10       Koreanic    724000000
# 11        Kra-Dai    707000000

# %%
df["Speakers"] = pd.to_numeric(df["Speakers"], errors="coerce")
df = df.dropna(subset=["Speakers"])
df = df.sort_values("Speakers", ascending=False)
df["Global Rank"] = range(1, len(df)+1)
df.head(10)
# Out:
#              Language         Family             Region   Speakers  \
# 379          Maithili   Sino-Tibetan              India  918000000
# 362             Hausa   Sino-Tibetan   Germany, Austria  918000000
# 153            Yoruba   Indo-Iranian          Worldwide  918000000
# 494           Kannada  Indo-European            Nigeria  918000000
# 46   Xiang (Hunanese)   Sino-Tibetan  China (Hong Kong)  918000000
# 440             Hausa  Indo-European              China  918000000
# 161  Xiang (Hunanese)  Austroasiatic              India  918000000
# 251            Korean  Indo-European    Pakistan, India  918000000
# 138             Hindi   Austronesian              India  460000000
# 190          Maithili        Japonic              India  460000000
#
#     Writing System ISO Code  Global Rank
# 379          Tamil       de            1
# 362       Ethiopic       jv            2
# 153          Latin       uk            3
# 494          Latin       pt            4
# 46           Latin       mr            5
# 440         Telugu       ko            6
# 161          Latin       uz            7
# 251          Latin       am            8
# 138          Latin       ff            9
# 190          Oriya      hsn           10

# %%
df_geo = df.copy()
df_geo["Region"] = df_geo["Region"].str.split(",")
df_geo = df_geo.explode("Region")
df_geo["Region"] = df_geo["Region"].str.strip()

# %%
spread = (
    df_geo.groupby("Language")["Region"]
    .nunique()
    .sort_values(ascending=False)
    .reset_index(name="Country Count")
)

spread.head(10)
# Out:
#            Language  Country Count
# 0           Marathi             14
# 1           Persian             14
# 2        Vietnamese             13
# 3      Odia (Oriya)             11
# 4            Awadhi             11
# 5           Burmese             11
# 6             Hausa             11
# 7  Xiang (Hunanese)             10
# 8           Bengali             10
# 9             Uzbek             10

# %%
merged = df.merge(spread, on="Language")

merged["Density Index"] = (
    merged["Speakers"] /
    merged["Country Count"]
)

merged.sort_values("Density Index", ascending=False).head(10)
# Out:
#              Language         Family             Region   Speakers  \
# 0            Maithili   Sino-Tibetan              India  918000000
# 55             Korean  Indo-European    Pakistan, India  918000000
# 22             Yoruba   Indo-Iranian          Worldwide  918000000
# 33            Kannada  Indo-European            Nigeria  918000000
# 103             Oromo         Turkic    Pakistan, India  460000000
# 42   Xiang (Hunanese)   Sino-Tibetan  China (Hong Kong)  918000000
# 43   Xiang (Hunanese)  Austroasiatic              India  918000000
# 10              Hausa   Sino-Tibetan   Germany, Austria  918000000
# 11              Hausa  Indo-European              China  918000000
# 82               Fula       Koreanic            Nigeria  460000000
#
#          Writing System ISO Code  Global Rank  Country Count  Density Index
# 0                 Tamil       de            1              7   1.311429e+08
# 55                Latin       am            8              7   1.311429e+08
# 22                Latin       uk            3              8   1.147500e+08
# 33                Latin       pt            4              9   1.020000e+08
# 103           Malayalam       ps           15              5   9.200000e+07
# 42                Latin       mr            5             10   9.180000e+07
# 43                Latin       uz            7             10   9.180000e+07
# 10             Ethiopic       jv            2             11   8.345455e+07
# 11               Telugu       ko            6             11   8.345455e+07
# 82   Simplified Chinese      yue           13              6   7.666667e+07

# %%
writing_power = (
    df.groupby("Writing System")["Speakers"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

writing_power
# Out:
#                Writing System     Speakers
# 0                       Latin  21429600000
# 1                  Devanagari   2858800000
# 2                       Tamil   2785900000
# 3                    Ethiopic   2191000000
# 4                     Chinese   2164000000
# 5                      Telugu   1668000000
# 6         Traditional Chinese   1642000000
# 7                Perso-Arabic   1637800000
# 8                      Arabic   1563000000
# 9          Simplified Chinese   1515000000
# 10  Kanji, Hiragana, Katakana   1381000000
# 11                   Cyrillic   1100000000
# 12                     Hangul   1053000000
# 13                      Oriya    972900000
# 14                    Burmese    906000000
# 15      Shahmukhi, Devanagari    768000000
# 16                    Kannada    741000000
# 17                  Malayalam    675000000
# 18                   Gujarati    671000000
# 19        Shahmukhi, Gurmukhi    513000000
# 20                    Bengali    499000000
# 21                       Thai    466000000

# %%
family_diversity = (
    df.groupby("Family")["Language"]
    .count()
    .sort_values(ascending=False)
    .reset_index(name="Language Count")
)

family_diversity
# Out:
#            Family  Language Count
# 0   Indo-European             228
# 1    Sino-Tibetan              76
# 2       Dravidian              36
# 3          Turkic              34
# 4    Afro-Asiatic              26
# 5    Austronesian              24
# 6     Niger-Congo              24
# 7    Indo-Iranian              16
# 8         Kra-Dai              12
# 9   Austroasiatic              10
# 10       Koreanic               8
# 11        Japonic               6

# %%
family_analysis = family_diversity.merge(
    family_power[["Family", "Speakers"]],
    on="Family"
)

family_analysis["Avg Speakers per Language"] = (
    family_analysis["Speakers"] /
    family_analysis["Language Count"]
)

family_analysis.sort_values("Avg Speakers per Language", ascending=False)
# Out:
#            Family  Language Count     Speakers  Avg Speakers per Language
# 9   Austroasiatic              10   2065000000               2.065000e+08
# 11        Japonic               6    860000000               1.433333e+08
# 7    Indo-Iranian              16   1995900000               1.247438e+08
# 1    Sino-Tibetan              76   9129900000               1.201303e+08
# 4    Afro-Asiatic              26   2718000000               1.045385e+08
# 6     Niger-Congo              24   2413000000               1.005417e+08
# 3          Turkic              34   3376000000               9.929412e+07
# 0   Indo-European             228  20953500000               9.190132e+07
# 10       Koreanic               8    724000000               9.050000e+07
# 2       Dravidian              36   2629900000               7.305278e+07
# 5    Austronesian              24   1628800000               6.786667e+07
# 8         Kra-Dai              12    707000000               5.891667e+07

# %%
script_efficiency = (
    df.groupby("Writing System")
    .agg({
        "Language": "count",
        "Speakers": "sum"
    })
    .reset_index()
)

script_efficiency["Speakers per Language"] = (
    script_efficiency["Speakers"] /
    script_efficiency["Language"]
)

script_efficiency.sort_values("Speakers per Language", ascending=False)
# Out:
#                Writing System  Language     Speakers  Speakers per Language
# 19                     Telugu         8   1668000000           2.085000e+08
# 18                      Tamil        16   2785900000           1.741188e+08
# 9   Kanji, Hiragana, Katakana        10   1381000000           1.381000e+08
# 7                    Gujarati         5    671000000           1.342000e+08
# 10                    Kannada         6    741000000           1.235000e+08
# 13                      Oriya         8    972900000           1.216125e+08
# 6                    Ethiopic        19   2191000000           1.153158e+08
# 11                      Latin       203  21429600000           1.055645e+08
# 3                     Chinese        21   2164000000           1.030476e+08
# 5                  Devanagari        28   2858800000           1.021000e+08
# 12                  Malayalam         7    675000000           9.642857e+07
# 21        Traditional Chinese        20   1642000000           8.210000e+07
# 8                      Hangul        13   1053000000           8.100000e+07
# 15      Shahmukhi, Devanagari        10    768000000           7.680000e+07
# 17         Simplified Chinese        20   1515000000           7.575000e+07
# 0                      Arabic        21   1563000000           7.442857e+07
# 14               Perso-Arabic        24   1637800000           6.824167e+07
# 2                     Burmese        14    906000000           6.471429e+07
# 20                       Thai         8    466000000           5.825000e+07
# 4                    Cyrillic        19   1100000000           5.789474e+07
# 16        Shahmukhi, Gurmukhi        10    513000000           5.130000e+07
# 1                     Bengali        10    499000000           4.990000e+07

# %%
import plotly.express as px

# %%
fig = px.treemap(
    df,
    path=["Family", "Writing System", "Language", "Region"],
    values="Speakers",
    title="Global Linguistic Power Structure: Multi-Layer Treemap",
)

fig.update_layout(
    margin=dict(t=50, l=0, r=0, b=0)
)

fig.show()
# Out:
# <div>                            <div id="d0490632-8763-486e-b598-32af9fa2a110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0490632-8763-486e-b598-32af9fa2a110")) {                    Plotly.newPlot(                        "d0490632-8763-486e-b598-32af9fa2a110",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Speakers=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Indo-European/Latin/Amharic/Afghanistan, Pakistan","Niger-Congo/Latin/Arabic/Afghanistan, Pakistan","Kra-Dai/Cyrillic/Bhojpuri/Afghanistan, Pakistan","Indo-European/Latin/Hindi/Afghanistan, Pakistan","Indo-European/Hangul/Japanese/Afghanistan, Pakistan","Indo-European/Tamil/Japanese/Afghanistan, Pakistan","Indo-European/Latin/Marathi/Afghanist